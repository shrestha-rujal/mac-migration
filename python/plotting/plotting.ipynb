# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('health_lifestyle_classification.csv')
data.head()
# Out:
#    survey_code  age  gender      height     weight        bmi  bmi_estimated  \
# 0            1   56    Male  173.416872  56.886640  18.915925      18.915925
# 1            2   69  Female  163.207380  97.799859  36.716278      36.716278
# 2            3   46    Male  177.281966  80.687562  25.673050      25.673050
# 3            4   32  Female  172.101255  63.142868  21.318480      21.318480
# 4            5   60  Female  163.608816  40.000000  14.943302      14.943302
#
#    bmi_scaled  bmi_corrected  waist_size  ...  sunlight_exposure  \
# 0   56.747776      18.989117   72.165130  ...               High
# 1  110.148833      36.511417   85.598889  ...               High
# 2   77.019151      25.587429   90.295030  ...               High
# 3   63.955440      21.177109  100.504211  ...               High
# 4   44.829907      14.844299   69.021150  ...               High
#
#    meals_per_day  caffeine_intake  family_history  pet_owner  \
# ...

# %%
data.isna().sum()
# Out:
# survey_code                     0
# age                             0
# gender                          0
# height                          0
# weight                          0
# bmi                             0
# bmi_estimated                   0
# bmi_scaled                      0
# bmi_corrected                   0
# waist_size                      0
# blood_pressure               7669
# heart_rate                  14003
# cholesterol                     0
# glucose                         0
# insulin                     15836
# sleep_hours                     0
# sleep_quality                   0
# work_hours                      0
# physical_activity               0
# daily_steps                  8329
# calorie_intake                  0
# sugar_intake                    0
# alcohol_consumption         42387
# smoking_level                   0
# water_intake                    0
# screen_time                     0
# stress_level                    0
# ...

# %%
data.describe()
# Out:
#          survey_code            age         height         weight  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000      48.525990     170.023707      70.064862
# std     28867.657797      17.886768       9.982798      14.693667
# min         1.000000      18.000000     140.000000      40.000000
# 25%     25000.750000      33.000000     163.306615      59.856938
# 50%     50000.500000      48.000000     170.016778      69.924141
# 75%     75000.250000      64.000000     176.728920      80.027418
# max    100000.000000      79.000000     210.000000     139.250894
#
#                  bmi  bmi_estimated     bmi_scaled  bmi_corrected  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       24.493876      24.493876      73.481627      24.494140
# std         5.951069       5.951069      17.853206       5.954184
# min         9.988495       9.988495      29.965484       9.893845
# ...

# %%
data.shape
# Out:
# (100000, 48)

# %%
data.isnull().sum()
# Out:
# survey_code                     0
# age                             0
# gender                          0
# height                          0
# weight                          0
# bmi                             0
# bmi_estimated                   0
# bmi_scaled                      0
# bmi_corrected                   0
# waist_size                      0
# blood_pressure               7669
# heart_rate                  14003
# cholesterol                     0
# glucose                         0
# insulin                     15836
# sleep_hours                     0
# sleep_quality                   0
# work_hours                      0
# physical_activity               0
# daily_steps                  8329
# calorie_intake                  0
# sugar_intake                    0
# alcohol_consumption         42387
# smoking_level                   0
# water_intake                    0
# screen_time                     0
# stress_level                    0
# ...

# %%
data.columns
# Out:
# Index(['survey_code', 'age', 'gender', 'height', 'weight', 'bmi',
#        'bmi_estimated', 'bmi_scaled', 'bmi_corrected', 'waist_size',
#        'blood_pressure', 'heart_rate', 'cholesterol', 'glucose', 'insulin',
#        'sleep_hours', 'sleep_quality', 'work_hours', 'physical_activity',
#        'daily_steps', 'calorie_intake', 'sugar_intake', 'alcohol_consumption',
#        'smoking_level', 'water_intake', 'screen_time', 'stress_level',
#        'mental_health_score', 'mental_health_support', 'education_level',
#        'job_type', 'occupation', 'income', 'diet_type', 'exercise_type',
#        'device_usage', 'healthcare_access', 'insurance', 'sunlight_exposure',
#        'meals_per_day', 'caffeine_intake', 'family_history', 'pet_owner',
#        'electrolyte_level', 'gene_marker_flag', 'environmental_risk_score',
#        'daily_supplement_dosage', 'target'],
#       dtype='object')

# %%
df = data[['survey_code', 'age', 'gender', 'height', 'weight', 'sleep_hours', 'sleep_quality', 'work_hours', 'physical_activity', 'daily_steps', 'sugar_intake', 'water_intake', 'screen_time', 'occupation', 'job_type', 'income', 'exercise_type', 'meals_per_day', 'pet_owner', 'sunlight_exposure']]

# %%
df.head()
# Out:
#    survey_code  age  gender      height     weight  sleep_hours sleep_quality  \
# 0            1   56    Male  173.416872  56.886640     6.475885          Fair
# 1            2   69  Female  163.207380  97.799859     8.428410          Good
# 2            3   46    Male  177.281966  80.687562     5.702164          Poor
# 3            4   32  Female  172.101255  63.142868     5.188316          Good
# 4            5   60  Female  163.608816  40.000000     7.912514          Good
#
#    work_hours  physical_activity   daily_steps  sugar_intake  water_intake  \
# 0    7.671313           0.356918  13320.942595     44.476887      1.694262
# 1    9.515198           0.568219  11911.201401     74.663405      0.716409
# 2    5.829853           3.764406   2974.035375     19.702382      2.487900
# 3    9.489693           0.889474   5321.539497     82.580050      2.643335
# 4    7.275450           2.901608   9791.376712     45.961322      1.968393
#
# ...

# %%
df.describe()
# Out:
#          survey_code            age         height         weight  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000      48.525990     170.023707      70.064862
# std     28867.657797      17.886768       9.982798      14.693667
# min         1.000000      18.000000     140.000000      40.000000
# 25%     25000.750000      33.000000     163.306615      59.856938
# 50%     50000.500000      48.000000     170.016778      69.924141
# 75%     75000.250000      64.000000     176.728920      80.027418
# max    100000.000000      79.000000     210.000000     139.250894
#
#          sleep_hours     work_hours  physical_activity   daily_steps  \
# count  100000.000000  100000.000000      100000.000000  91671.000000
# mean        7.002008       8.001331           3.038344   7012.925748
# std         1.496821       1.994723           1.884475   2488.989356
# min         3.000000       0.000000           0.000000   1000.000000
# ...

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.isna().sum()
# Out:
# survey_code              0
# age                      0
# gender                   0
# height                   0
# weight                   0
# sleep_hours              0
# sleep_quality            0
# work_hours               0
# physical_activity        0
# daily_steps           8329
# sugar_intake             0
# water_intake             0
# screen_time              0
# occupation               0
# job_type                 0
# income                8470
# exercise_type        24969
# meals_per_day            0
# pet_owner                0
# sunlight_exposure        0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# /var/folders/mw/92tzvh5x7098x2prk2dnt57w0000gn/T/ipykernel_4133/1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.shape
# Out:
# (62940, 20)

# %%
df.head()
# Out:
#    survey_code  age  gender      height     weight  sleep_hours sleep_quality  \
# 0            1   56    Male  173.416872  56.886640     6.475885          Fair
# 1            2   69  Female  163.207380  97.799859     8.428410          Good
# 2            3   46    Male  177.281966  80.687562     5.702164          Poor
# 3            4   32  Female  172.101255  63.142868     5.188316          Good
# 6            7   78  Female  166.164733  65.035212     4.342973     Excellent
#
#    work_hours  physical_activity   daily_steps  sugar_intake  water_intake  \
# 0    7.671313           0.356918  13320.942595     44.476887      1.694262
# 1    9.515198           0.568219  11911.201401     74.663405      0.716409
# 2    5.829853           3.764406   2974.035375     19.702382      2.487900
# 3    9.489693           0.889474   5321.539497     82.580050      2.643335
# 6    6.206772           0.294640   7968.302176     53.836960      1.704180
#
# ...

# %%
len(data.dropna())
# Out:
# 14482

# %%
df.occupation.unique()
# Out:
# array(['Farmer', 'Engineer', 'Teacher', 'Driver', 'Artist', 'Doctor'],
#       dtype=object)

# %%
df.job_type.unique()
# Out:
# array(['Tech', 'Office', 'Labor', 'Unemployed', 'Service', 'Healthcare'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['survey_code', 'age', 'gender', 'height', 'weight', 'sleep_hours',
#        'sleep_quality', 'work_hours', 'physical_activity', 'daily_steps',
#        'sugar_intake', 'water_intake', 'screen_time', 'occupation', 'job_type',
#        'income', 'exercise_type', 'meals_per_day', 'pet_owner',
#        'sunlight_exposure'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.pointplot(data = df, x = 'job_type', y = 'weight')
# Out:
# <Axes: xlabel='job_type', ylabel='weight'>

# %%
df2 = df.sample(n=1000)

# %%
sns.barplot(data=df2, x = 'occupation', y = 'income')
# Out:
# <Axes: xlabel='occupation', ylabel='income'>
